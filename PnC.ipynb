# %% [markdown]
# L2-L4
# 决策模型
# 马尔可夫模型
# 数学
# 路口博弈
# 二次优化算法
# 局部多项式算法，平滑处理
# 全局规划算法
# 控制算法（k2，PID，PC等）

# %% [markdown]
# 任职要求：
#
# 1. 熟练掌握线性代数、微积分、凸优化等数学工具；
#
# 2. 熟悉经典控制理论（时域，频域系统分析方法和数学工具）；
#
# 3. 熟悉现代控制理论，基本控制方法例如状态空间方程分析和设计控制器方法，高级控制方法例如LQR, LQG, MPC, MRAC, 鲁棒性控制等；
#
# 4. 熟悉非线性系统的稳定性分析和控制器设计方法；
#
# 5. 熟练使用C++; 熟悉数据结构和算法（非计算机专业要求）；
#
# 6. 机械工程、电子信息工程、机器人、控制工程、应用数学硕士及以上学历；或同等专业水平。
#
# 若能满足如下条件的其中一个，会适当加分：
#
# 1. 有车辆或移动机器人控制器设计经验；
#
# 2. 车辆运动模拟仿真平台搭建经验；
#
# 3. 熟悉卡尔曼滤波器，状态观测器，信号处理；
#
# 4. 熟悉GPS、IMU、LIDAR等车载传感器原理；
#
# 5. 控制和机器人领域会议或期刊作者（例如ACC，CDC，IROS，ICRA，TAC等）。

# %% [markdown]
# 任职要求：
#
# 1.  相关专业本科以上学历（机器人，计算机，自动化，数学等）；
#
# 2. 熟悉行为预测相关算法（单/多智能体交互等）；
#
# 3. 熟悉目标跟踪相关算法（单/多智能体追踪，Kalman filter等）；
#
# 4. 熟悉机器学习相关算法（MLP，SVM，深度学习等）；
#
# 5. 有机器学习开发经验（数据预处理，模型训练，模型验证等）；
#
# 6. 熟悉轨迹生成相关算法（A*，RRT，Lattice planner等）；
#
# 7. 有扎实的C++编程基础（算法，数据结构等）。
#
#
#
# 若能满足如下条件的其中一个，会适当加分：
#
# 1. 有无人车、 无人机、机器人等相关经验；
#
# 2. 有编程竞赛经验（NOI，IOI，ACM等）。

# %% [markdown]
# 任职要求(运动规划算法开发工程师，社)：
#
# 1. 熟悉路径规划相关算法（A*，RRT，lattice planner等）；
#
# 2. 具备良好的数学基础（几何，统计，图形学，优化等）；
#
# 3. 具备良好的机器学习基础（数据收集与分析，特征提取，模型训练及调试，部署等）；
#
# 4. 具备扎实的C++编程基础（算法，数据结构等）；
#
# 5. 具备良好的沟通及团队合作能力；
#
# 6. 相关专业本科以上学历（机器人，计算机，自动化，数学等)。
#
#
#
# 若能满足如下条件的其中一个，会适当加分：
#
# 1. 有无人车、 无人机、机器人等相关行业经验；
#
# 2. 有编程竞赛经验（NOI，IOI，ACM等）;
#
# 3. 在人工智能，机器人领域会议和期刊发表过论文。

# %% [markdown]
# 任职要求：（控制算法工程师，社）
#
# 1. 熟练掌握线性代数、微积分、凸优化等数学工具；
#
# 2. 熟悉经典控制理论（时域，频域系统分析方法和数学工具）；
#
# 3. 熟悉现代控制理论，基本控制方法例如状态空间方程分析和设计控制器方法，高级控制方法例如LQR, LQG, MPC, MRAC, 鲁棒性控制等；
#
# 4. 熟悉非线性系统的稳定性分析和控制器设计方法；
#
# 5. 熟练使用C++; 熟悉数据结构和算法（非计算机专业要求）；
#
# 6. 机械工程、电子信息工程、机器人、控制工程、应用数学硕士及以上学历；或同等专业水平。
#
# 若能满足如下条件的其中一个，会适当加分：
#
# 1. 有车辆或移动机器人控制器设计经验；
#
# 2. 车辆运动模拟仿真平台搭建经验；
#
# 3. 熟悉卡尔曼滤波器，状态观测器，信号处理；
#
# 4. 熟悉GPS、IMU、LIDAR等车载传感器原理；
#
# 5. 控制和机器人领域会议或期刊作者（例如ACC，CDC，IROS，ICRA，TAC等）。

# %% [markdown]
#     MySQL（5月）
#     Linux（华为）
#     计算机网络（华为）
#     C++ (5月，黑马短入门，然后配合书，华为)
#     RL（华为）
#     DL（华为）
#     信号与系统（傅立叶，卡尔曼滤波）（6月）
#     凸优化（二次优化，平滑处理，最优化理论，运筹学）（7月）
#     控制理论（8月）
#     博弈论（9月）
#     行为预测，目标跟踪，单多智能体交互（10月）
#     路径规划算法（局部和全局）
#     数学（线代，微积分）
#     八股（计网，操作系统的复习，10月）
